# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from plot_cmp import plot_compare

# %%
data=pd.read_csv("result/mnist_t4.csv")
data.head()
# Out:
#         acc   val_acc  sigma    lambda          n1          n2          n3  \
# 0  0.999992  0.976333   0.25  0.001231  440.000000  356.333333  208.333333
# 1  1.000000  0.976667   0.25  0.001346  477.000000  398.666667  249.000000
# 2  0.999984  0.978571   0.25  0.001295  446.666667  366.333333  212.666667
# 3  0.999984  0.978381   0.25  0.001269  484.666667  396.000000  243.666667
# 4  0.999976  0.976905   0.25  0.001244  460.333333  372.666667  227.333333
#
#           n4       sp1       sp2       sp3       sp4
# 0  74.666667  0.487270  0.295425  0.450767  0.263667
# 1  82.666667  0.427027  0.145222  0.311767  0.183333
# 2  77.000000  0.481587  0.297914  0.445278  0.234000
# 3  83.666667  0.416023  0.155239  0.315689  0.167333
# 4  77.333333  0.450520  0.222814  0.386122  0.232333

# %%
sigma=data["sigma"].drop_duplicates().tolist()
data_list=[]
data_label=[]
for sig in sigma:
    data_list.append(data[data["sigma"]==sig])
    data_label.append(sig)
bench_list=["SG_L1","L1_NN","L2_NN"]
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Feature_selection",dataset_name="mnist",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Hidden_layer_node_pruning",dataset_name="mnist",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Sparsity",dataset_name="mnist",bench_list=bench_list)
