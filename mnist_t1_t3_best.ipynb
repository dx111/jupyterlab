# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plot_cmp import plot_compare

# %%
type1=pd.read_csv("result/mnist_type1_result.csv")
type3=pd.read_csv("result/mnist_type3_result.csv")
data_list=[type1,type3]
dataset_label_list=["type1","type3"]
bench_list=["SG_L1","L2_NN","L1_NN"]
fig=plot_compare(dataset_list=data_list,data_label=dataset_label_list,compare_type="Feature_selection",dataset_name="mnist",bench_list=bench_list)
fig=plot_compare(dataset_list=data_list,data_label=dataset_label_list,compare_type="Hidden_layer_node_pruning",dataset_name="mnist",bench_list=bench_list)
fig=plot_compare(dataset_list=data_list,data_label=dataset_label_list,compare_type="Sparsity",dataset_name="mnist",bench_list=bench_list)
