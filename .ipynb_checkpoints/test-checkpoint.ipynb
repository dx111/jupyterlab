# %%
import numpy as np

# %%
a=np.linspace(0.0001,0.001,10).tolist()+np.linspace(0.002,0.01,9).tolist()+np.linspace(0.02,0.1).tolist()
# Out:
# [0.0001,
#  0.00019999999999999998,
#  0.0003,
#  0.00039999999999999996,
#  0.0005,
#  0.0006000000000000001,
#  0.0007,
#  0.0007999999999999999,
#  0.0009,
#  0.001,
#  0.002,
#  0.003,
#  0.004,
#  0.005,
#  0.006,
#  0.007,
#  0.008,
#  0.009000000000000001,
#  0.01,
#  0.02,
#  0.02163265306122449,
#  0.02326530612244898,
#  0.02489795918367347,
#  0.026530612244897958,
#  0.02816326530612245,
#  0.02979591836734694,
#  0.03142857142857143,
#  0.03306122448979592,
#  0.03469387755102041,
#  0.0363265306122449,
#  0.037959183673469385,
#  0.03959183673469388,
#  0.04122448979591837,
#  0.04285714285714286,
#  0.04448979591836735,
#  0.046122448979591835,
#  0.04775510204081633,
#  0.04938775510204082,
#  0.05102040816326531,
#  0.0526530612244898,
#  0.054285714285714284,
#  0.05591836734693878,
#  0.05755102040816326,
#  0.05918367346938776,
#  0.06081632653061225,
#  0.062448979591836734,
#  0.06408163265306123,
#  0.06571428571428571,
#  0.0673469387755102,
# ...

# %%
x
# Out:
# array([ 1.00230524,  1.08504631,  1.17461773,  1.27158334,  1.37655353,
#         1.49018909,  1.61320536,  1.74637671,  1.89054146,  2.04660713,
#         2.21555614,  2.39845202,  2.59644609,  2.81078473,  3.0428172 ,
#         3.29400412,  3.56592672,  3.86029674,  4.17896723,  4.52394422,
#         4.89739933,  5.30168344,  5.73934153,  6.21312863,  6.72602722,
#         7.28126599,  7.88234015,  8.53303345,  9.23744199, 10.        ])
