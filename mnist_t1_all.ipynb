# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from plot_cmp import plot_compare

# %%
data=pd.read_csv("all_res/mnist_type1_all.csv")
data.head()
# Out:
#         acc   val_acc   type   sigma    lambda     n1          n2          n3  \
# 0  0.999587  0.971381  type1  0.0001  0.000421  691.0  400.000000  300.000000
# 1  0.999952  0.976937  type1  0.0001  0.000832  630.0  359.666667  275.666667
# 2  0.999976  0.975587  type1  0.0001  0.001244  621.0  362.666667  267.666667
# 3  0.999730  0.974365  type1  0.0001  0.001655  655.0  230.666667  239.666667
# 4  0.999595  0.973857  type1  0.0001  0.002066  646.0  179.000000  233.333333
#
#            n4       sp1       sp2       sp3       sp4
# 0  100.000000  0.152482  0.005264  0.005589  0.005667
# 1   94.000000  0.535321  0.160906  0.124611  0.064000
# 2   93.333333  0.651110  0.261936  0.177689  0.070667
# 3   94.000000  0.734601  0.631400  0.243044  0.061333
# 4   91.333333  0.791251  0.694500  0.296333  0.087333

# %%
data=data[data["val_acc"]>0.8]

# %%
fig3=plt.figure()
d0001=data[data["sigma"] ==0.0001]
d0003=data[data["sigma"] ==0.0003]
d0005=data[data["sigma"] ==0.0005]
d0007=data[data["sigma"] ==0.0007]
d0009=data[data["sigma"] ==0.0009]

d0000_data=[d0001,d0003,d0005,d0007,d0009]
d0000_label=["d0001","d0003","d0005","d0007","d0009"]
bench_list=["SG_L1","L1_NN","L2_NN"]
fig=plot_compare(dataset_list=d0000_data,data_label=d0000_label,compare_type="Feature_selection",dataset_name="mnist",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=d0000_data,data_label=d0000_label,compare_type="Hidden_layer_node_pruning",dataset_name="mnist",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=d0000_data,data_label=d0000_label,compare_type="Sparsity",dataset_name="mnist",bench_list=bench_list)
