# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from plot_cmp import plot_compare

# %%
data=pd.read_csv("all_res/cov_t4_all.csv")
data.head()
# Out:
#         acc   val_acc   type  sigma    lambda         n1    n2    n3  \
# 0  0.831058  0.827814  type4  0.125  0.000132  54.000000  50.0  50.0
# 1  0.602009  0.601285  type4  0.125  0.000254  53.666667  50.0  50.0
# 2  0.364917  0.364917  type4  0.125  0.000498  54.000000  50.0  50.0
# 3  0.405521  0.405506  type4  0.125  0.000987  54.000000  50.0  50.0
# 4  0.364841  0.364841  type4  0.125  0.001963  54.000000  50.0  50.0
#
#           n4       sp1       sp2       sp3       sp4
# 0  19.666667  0.016049  0.001733  0.002333  0.016667
# 1  20.000000  0.007654  0.002133  0.001000  0.000000
# 2  20.000000  0.014198  0.000933  0.001000  0.000000
# 3  20.000000  0.007037  0.008800  0.001000  0.002381
# 4  20.000000  0.010123  0.008533  0.000333  0.002381

# %%
data=data[data["val_acc"]>0.82]

# %%
sigma=data["sigma"].drop_duplicates().tolist()
data_list=[]
data_label=[]
for sig in sigma:
    data_list.append(data[data["sigma"]==sig])
    data_label.append(sig)
bench_list=["SG_L1","L1_NN","L2_NN"]
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Feature_selection",dataset_name="covtype",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Hidden_layer_node_pruning",dataset_name="covtype",bench_list=bench_list)

# %%
fig=plot_compare(dataset_list=data_list,data_label=data_label,compare_type="Sparsity",dataset_name="covtype",bench_list=bench_list)
